# %%
import numpy as np
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Input, Dense, Dropout
import os

# %%
image_shape = (299, 299, 3)

# %%
featureExtractor = InceptionV3(
    include_top=False, 
    weights='imagenet',
    pooling='avg', 
    input_shape=image_shape, 
    classes=1000)
featureExtractor.compile('sgd', 'mse')

# %%
datasetPath = '../datasets/coco/train2017/'
vectorsPath = 'data/vectors_inception/'

# %%
imgpaths = [os.path.join(root, f) 
            for root, _, files in os.walk(datasetPath) 
            for f in files if f.endswith('.jpg')]
print(len(imgpaths))
imgpaths = imgpaths[0: 1000]

# %%
def extractAndSaveVectorsForBatch(batchImgPaths):
    batchSize = len(batchImgPaths)
    batch = np.zeros((batchSize,) + image_shape, dtype=np.float)
    
    for i in range(0, batchSize):
        img = image.img_to_array(image.load_img(batchImgPaths[i], target_size=image_shape))
        batch[i] = preprocess_input(img)
        
    batchVectors = featureExtractor.predict_on_batch(batch).astype(np.float16)
    for i in range(0, batchSize):
        np.save(batchImgPaths[i].replace(datasetPath, vectorsPath) + '.npy', batchVectors[i])

# %%
batchSize = 64
printEvery = 8
imgCount = len(imgpaths)
for i in range(0, imgCount, batchSize):
    extractAndSaveVectorsForBatch(imgpaths[i: i+batchSize])
    if not i % printEvery*batchSize:
        print('extracted vectors for %s images of %s' % (min(i+batchSize, imgCount), imgCount))
print('extracted vectors for every image')
# Out:
# extracted vectors for 64 images of 10000
# extracted vectors for 128 images of 10000
# extracted vectors for 192 images of 10000
# extracted vectors for 256 images of 10000
# extracted vectors for 320 images of 10000
# extracted vectors for 384 images of 10000
# extracted vectors for 448 images of 10000
# extracted vectors for 512 images of 10000
# extracted vectors for 576 images of 10000
# extracted vectors for 640 images of 10000
# extracted vectors for 704 images of 10000
# extracted vectors for 768 images of 10000
# extracted vectors for 832 images of 10000
# extracted vectors for 896 images of 10000
# extracted vectors for 960 images of 10000
# extracted vectors for 1024 images of 10000
# extracted vectors for 1088 images of 10000
# extracted vectors for 1152 images of 10000
# extracted vectors for 1216 images of 10000
# extracted vectors for 1280 images of 10000
# extracted vectors for 1344 images of 10000
# extracted vectors for 1408 images of 10000
# ...

# %%
imgVectors = []
for imgpath in imgpaths:
    vectorpath = imgpath.replace(datasetPath, vectorsPath) + '.npy'
    imgVectors.append(np.load(vectorpath))

print(len(imgVectors))
    
inceptionVectors = np.array(imgVectors)
print('loaded all inception image vectors')
# Out:
# loaded all inception image vectors

# %%
imgVectors = []
for imgpath in imgpaths:
    vectorpath = imgpath.replace(datasetPath, vectorsPath.replace('inception', 'resnet')) + '.npy'
    imgVectors.append(np.load(vectorpath))

print(len(imgVectors))

resnetVectors = np.array(imgVectors)
print('loaded all resnet image vectors')
# Out:
# loaded all resnet image vectors

# %%
def getAugmentModel(input_size, output_size, embedding_size):
    inp = Input((input_size,))
    enc1 = Dense(embedding_size*4, activation='relu')(inp)
    enc2 = Dense(embedding_size*2, activation='relu')(enc1)
    bottleneck = Dense(embedding_size, activation='relu')(enc2)
    d = Dropout(0.3)(bottleneck)
    dec1 = Dense(embedding_size*2, activation='relu')(d)
    dec2 = Dense(embedding_size*4, activation='relu')(dec1)
    out = Dense(output_size, activation='relu')(dec2)
    model = Model(inputs=inp, outputs=out)
    model.compile('adam', 'mse')
    return model

# %%
model = getAugmentModel(
    input_size=resnetVectors.shape[-1], 
    output_size=inceptionVectors.shape[-1], 
    embedding_size=1024)

# %%
model.fit(inceptionVectors, resnetVectors, batch_size=64, epochs=100, validation_split=0.05)
# Out:
# Train on 9500 samples, validate on 500 samples
# Epoch 1/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.7299 - val_loss: 0.5618
# Epoch 2/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.5233 - val_loss: 0.5124
# Epoch 3/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.4879 - val_loss: 0.4830
# Epoch 4/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.4537 - val_loss: 0.4491
# Epoch 5/100
#   64/9500 [..............................]
#  - ETA: 5s - loss: 0.4165
# ...
# 9500/9500 [==============================] - 5s - loss: 0.4260 - val_loss: 0.4283
# Epoch 6/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.4105 - val_loss: 0.4199
# Epoch 7/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.3990 - val_loss: 0.4087
# Epoch 8/100
# ...
# 9500/9500 [==============================] - 5s - loss: 0.3884 - val_loss: 0.3988
# Epoch 9/100
# ...

# %%
def getEncoderModel(model):
    encoder = Model(inputs=model.inputs[0], outputs=model.layers[3].output)
    encoder.compile('adam', 'mse')
    return encoder

# %%
encoder = getEncoderModel(model)

# %%
embededVectors = encoder.predict(inceptionVectors, verbose=1)
# Out:
# ...
#  9920/10000 [============================>.] - ETA: 0s

# %%
from tsne import bh_sne
import cv2

# %%
embededVectors2d = bh_sne(embededVectors.astype(np.float))

# %%
canvasWidth = 6000
canvas = np.zeros((canvasWidth, canvasWidth, 3), dtype=np.uint8)
imgWidth = round((embededVectors2d.max() - embededVectors2d.min())*canvasWidth/10000)
imgWidth -= int(imgWidth % 2)

# %%
imgWidth = int(imgWidth)

# %%
minx = embededVectors2d[:, 0].min()
miny = embededVectors2d[:, 1].min()

embededVectors2d[:, 0] -= minx
embededVectors2d[:, 1] -= miny

maxx = embededVectors2d[:, 0].max()
maxy = embededVectors2d[:, 1].max()

canvasWidth = canvas.shape[1]
for i, imgpath in enumerate(imgpaths):
    imx = int((embededVectors2d[i, 0]/maxx * (canvasWidth-imgWidth)) + imgWidth/2)
    imy = int((embededVectors2d[i, 1]/maxy * (canvasWidth-imgWidth)) + imgWidth/2)
    scaledimage = cv2.resize(cv2.imread(imgpath), (imgWidth, imgWidth))
    canvas[imx - imgWidth/2: imx+imgWidth/2, imy-imgWidth/2: imy+imgWidth/2] = scaledimage
    if not i % 100:
        print('added %s images on canvas ' % i)
# Out:
# added  0mages on canvas
# added  100mages on canvas
# added  200mages on canvas
# added  300mages on canvas
# added  400mages on canvas
# added  500mages on canvas
# added  600mages on canvas
# added  700mages on canvas
# added  800mages on canvas
# added  900mages on canvas
# added  1000mages on canvas
# added  1100mages on canvas
# added  1200mages on canvas
# added  1300mages on canvas
# added  1400mages on canvas
# added  1500mages on canvas
# added  1600mages on canvas
# added  1700mages on canvas
# added  1800mages on canvas
# added  1900mages on canvas
# added  2000mages on canvas
# added  2100mages on canvas
# added  2200mages on canvas
# added  2300mages on canvas
# added  2400mages on canvas
# added  2500mages on canvas
# added  2600mages on canvas
# added  2700mages on canvas
# added  2800mages on canvas
# added  2900mages on canvas
# added  3000mages on canvas
# added  3100mages on canvas
# added  3200mages on canvas
# added  3300mages on canvas
# ...

# %%
cv2.imwrite('tsneCanvasEmbeded.png', canvas)
# Out:
# True
